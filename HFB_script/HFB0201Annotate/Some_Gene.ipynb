# %%
import pandas as pd
import scanpy as sc 
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import rcParams
import os,re
import scanpy as sc

# %%
adata1=sc.read_h5ad('/home/maolp/data5/Gaofeng_All_matrix/Allcount/All_scanpyData/Data/Scanpy_merge_rmdoubulet_UMAP_label_lastCell.h5ad')

# %%
sc.pl.umap(adata1,color=["IFIT2","IFIT3"])

# %%
sc.pl.umap(adata1,color=["IFIT2","IFIT3"],title='PBMC')

# %%
sc.pl.umap(adata1,color=["SOX4",'PRDX2'])

# %%
sc.pl.umap(adata1[adata1.obs.New_Body.isin(['PBMC'])],color=["SOX4",'PRDX2'])
